# %%
documents = [
    "I love machine learning",
    "I love deep learning",
    "Machine learning is powerful"
]

words = sorted(set(" ".join(documents).lower().split()))

one_hot = {}
for i, word in enumerate(words): 
    vector = [0] * len(words)
    vector[i] = 1
    one_hot[word] = vector

print("Vocabulary:", words)
print("One-Hot Encoding:")
for word, vec in one_hot.items():
    print(word, ":", vec)
# Out:
# Vocabulary: ['deep', 'i', 'is', 'learning', 'love', 'machine', 'powerful']
# One-Hot Encoding:
# deep : [1, 0, 0, 0, 0, 0, 0]
# i : [0, 1, 0, 0, 0, 0, 0]
# is : [0, 0, 1, 0, 0, 0, 0]
# learning : [0, 0, 0, 1, 0, 0, 0]
# love : [0, 0, 0, 0, 1, 0, 0]
# machine : [0, 0, 0, 0, 0, 1, 0]
# powerful : [0, 0, 0, 0, 0, 0, 1]
