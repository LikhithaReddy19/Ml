# %%
data = {
    "location": "Hyderabad, Secunderabad",
    "person": "Rahul Verma",
    "organization": "Wipro"
}

print(data)
# Out:
# {'location': 'Hyderabad, Secunderabad', 'person': 'Rahul Verma', 'organization': 'Wipro'}
